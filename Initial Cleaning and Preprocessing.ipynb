# %% [markdown]
# # Precleaning/Processing

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Precleaning/Processing Orders.csv

# %%
df_orders = pd.read_csv("orders.csv", delimiter = ';' )
df_orders
# Out:
#           id                created_at  user_id  product_id  discount  \
# 0          1  2019-02-11T21:40:27.892Z        1          14   0.00000
# 1          2  2018-05-15T08:04:04.580Z        1         123   0.00000
# 2          3  2019-12-06T22:22:48.544Z        1         105   6.41668
# 3          4  2019-08-22T16:30:42.392Z        1          94   0.00000
# 4          5  2018-10-10T03:34:47.309Z        1         132   0.00000
# ...      ...                       ...      ...         ...       ...
# 18755  18756  2018-09-07T16:05:20.186Z     2499         165   0.00000
# 18756  18757  2018-12-13T08:54:11.721Z     2499         131   0.00000
# 18757  18758  2018-08-10T11:18:20.444Z     2499         127   0.00000
# 18758  18759  2019-12-25T09:40:29.152Z     2500          45   0.00000
# 18759  18760  2020-03-28T10:12:06.681Z     2500         138   0.00000
#
#        quantity  subtotal   tax     total
# 0             2   37.6481  2.07   39.7181
# 1             3  110.9310  6.10  117.0380
# 2             2   52.7235  2.90   55.6221
# 3             6  109.2190  6.01  115.2210
# 4             5  127.8820  7.03  134.9420
# ...         ...       ...   ...       ...
# 18755         4   38.3045  2.49   79.5597
# 18756         2  113.1170  7.35   75.1032
# 18757         7  134.4800  8.74   82.0753
# 18758         2  118.0500  7.08  103.5760
# 18759         1  113.9510  6.84  122.3940
#
# [18760 rows x 9 columns]

# %%
#Checking missing value
df_orders.isnull().sum()
# Out:
# id            0
# created_at    0
# user_id       0
# product_id    0
# discount      0
# quantity      0
# subtotal      0
# tax           0
# total         0
# dtype: int64

# %%
#Dropping subtotal because of inconsistency with price, unneccessary columns
df_ordersnew = df_orders.drop(["subtotal","tax","total","discount"],axis= 1)
df_ordersnew


df_ordersnew["date_only"] = pd.to_datetime(df_ordersnew["created_at"].str[:10])
df_ordersnew
# Out:
#           id                created_at  user_id  product_id  quantity  \
# 0          1  2019-02-11T21:40:27.892Z        1          14         2
# 1          2  2018-05-15T08:04:04.580Z        1         123         3
# 2          3  2019-12-06T22:22:48.544Z        1         105         2
# 3          4  2019-08-22T16:30:42.392Z        1          94         6
# 4          5  2018-10-10T03:34:47.309Z        1         132         5
# ...      ...                       ...      ...         ...       ...
# 18755  18756  2018-09-07T16:05:20.186Z     2499         165         4
# 18756  18757  2018-12-13T08:54:11.721Z     2499         131         2
# 18757  18758  2018-08-10T11:18:20.444Z     2499         127         7
# 18758  18759  2019-12-25T09:40:29.152Z     2500          45         2
# 18759  18760  2020-03-28T10:12:06.681Z     2500         138         1
#
#        date_only
# 0     2019-02-11
# 1     2018-05-15
# 2     2019-12-06
# 3     2019-08-22
# 4     2018-10-10
# ...          ...
# 18755 2018-09-07
# 18756 2018-12-13
# 18757 2018-08-10
# 18758 2019-12-25
# 18759 2020-03-28
#
# [18760 rows x 6 columns]

# %%
df_ordersnew.isnull().sum()
# Out:
# id            0
# created_at    0
# user_id       0
# product_id    0
# quantity      0
# date_only     0
# dtype: int64

# %% [markdown]
# ### Precleaning/Processing products.csv

# %%
df_products = pd.read_csv("products.csv", delimiter = ';' )

# %%
df_productsnew = df_products.drop(["ean","quantity","created_at"], axis= 1)
df_productsnew
# Out:
#       id   category    price  rating                      title  \
# 0      1      Gizmo  29.4633     4.6        Rustic Paper Wallet
# 1      2  Doohickey  70.0799     0.0         Small Marble Shoes
# 2      3  Doohickey  35.3887     4.0  Synergistic Granite Chair
# 3      4  Doohickey  73.9918     3.0    Enormous Aluminum Shirt
# 4      5     Gadget  82.7451     4.0     Enormous Marble Wallet
# ..   ...        ...      ...     ...                        ...
# 195  196     Widget  46.7641     0.0    Heavy-Duty Linen Toucan
# 196  197      Gizmo  46.7641     4.6  Aerodynamic Concrete Lamp
# 197  198      Gizmo  46.7641     4.1      Enormous Copper Shirt
# 198  199     Widget  76.9533     3.6      Mediocre Leather Coat
# 199  200     Gadget  48.8026     4.0      Intelligent Steel Car
#
#                                   vendor
# 0           Swaniawski, Casper and Hilll
# 1                   Balistreri-Ankunding
# 2             Murray, Watsica and Wunsch
# 3                 Regan Bradtke and Sons
# 4              Price, Schultz and Daniel
# ..                                   ...
# 195                    Balistreri-Muller
# 196                  Erika Volkman Group
# 197  Considine, Schamberger and Schiller
# 198          Gulgowski, Grimes and Mayer
# 199           Pouros, Nitzsche and Mayer
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Precleaning/Processing reviews.csv

# %%
df_reviews = pd.read_csv("reviews.csv", delimiter = ';' )

# %%
df_reviewsnew = df_reviews.drop(["created_at"],axis= 1)
df_reviewsnew
# Out:
#         id          reviewer  product_id  rating  \
# 0        1            christ           1       5
# 1        2            xavier           1       4
# 2        3  cameron.nitzsche           1       5
# 3        4   barbara-shields           1       4
# 4        5           clement           1       5
# ...    ...               ...         ...     ...
# 1107  1108            dandre         200       4
# 1108  1109              will         200       3
# 1109  1110     cecilia.hyatt         200       4
# 1110  1111           delbert         200       5
# 1111  1112           terrell         200       4
#
#                                                    body
# 0     Ad perspiciatis quis et consectetur. Laboriosa...
# 1     Reprehenderit non error architecto consequatur...
# 2     In aut numquam labore fuga. Et tempora sit et ...
# 3     Est accusamus provident non animi labore minus...
# 4     Id sed sint corrupti molestias ad alias aut in...
# ...                                                 ...
# 1107  Quia natus eaque odit aperiam quasi ea. Fugit ...
# 1108  Alias exercitationem quo aut rem accusamus quo...
# 1109  Et doloribus quo laudantium earum accusamus pa...
# 1110  Eligendi id adipisci quis quaerat est dolorem ...
# 1111  Eligendi cumque et quam qui. Quo facilis venia...
#
# [1112 rows x 5 columns]

# %% [markdown]
# ### Precleaning/Processing users.csv

# %%
df_users = pd.read_csv("users.csv", delimiter = ';' ,encoding='latin-1')
df_users
# Out:
#         id                created_at                 name  \
# 0        1  2017-10-07T01:34:35.462Z         Hudson Borer
# 1        2  2018-04-09T12:10:05.167Z  Domenica Williamson
# 2        3  2017-06-27T06:06:20.625Z          Lina Heaney
# 3        4  2019-02-21T13:59:15.348Z         Arnold Adams
# 4        5  2017-09-05T03:36:44.811Z    Dominique Leffler
# ...    ...                       ...                  ...
# 2495  2496  2018-11-26T04:53:41.010Z          Jettie Yost
# 2496  2497  2017-01-05T02:58:59.217Z         Sadye Gibson
# 2497  2498  2016-08-31T11:49:59.777Z        Verner Hamill
# 2498  2499  2017-03-24T09:27:51.686Z           Cloyd Beer
# 2499  2500  2018-03-30T18:16:16.900Z        Kenny Schmidt
#
#                               email                       address  \
# 0            borer-hudson@yahoo.com  9611-9809 West Rosedale Road
# 1     williamson-domenica@yahoo.com                101 4th Street
# 2             lina.heaney@yahoo.com          29494 Anderson Drive
# 3            adams.arnold@gmail.com      2-7900 Cuerno Verde Road
# 4     leffler.dominique@hotmail.com            761 Fish Hill Road
# ...                             ...                           ...
# 2495          jettie-yost@gmail.com     22000-22998 County Road G
# 2496         sadye.gibson@gmail.com     23402 Camp Arrowhead Road
# 2497        verner.hamill@gmail.com                186 4500 South
# 2498           cloyd-beer@gmail.com       15708 East Lincoln Road
# 2499        kenny-schmidt@yahoo.com      14933 Walton-Verona Road
#
#              city state    zip  birth_date  latitude  longitude  \
# 0      Wood River    NE  68883  1986-12-12   40.7132   -98.5260
# 1       Searsboro    IA  50242  1967-06-10   41.5813   -92.6991
# 2       Sandstone    MN  55072  1961-12-18   46.1197   -92.8416
# 3             Rye    CO  81069  1992-08-12   37.9203  -104.9730
# 4     Beaver Dams    NY  14812  1974-04-20   42.3490   -77.0567
# ...           ...   ...    ...         ...       ...        ...
# 2495         Yuma    CO  80759  1988-05-15   39.9009  -102.6890
# 2496        Lewes    DE  19958  1986-06-12   38.6579   -75.1427
# 2497      Milford    UT  84751  1962-07-29   38.3279  -113.0120
# 2498      Spokane    WA  99217  1964-08-13   47.7267  -117.1940
# 2499       Verona    KY  41092  1962-02-23   38.8216   -84.6590
#
#                                   password     source
# 0     ccca881f-3e4b-4e5c-8336-354103604af6    Twitter
# 1     eafc45bf-cf8e-4c96-ab35-ce44d0021597  Affiliate
# 2     36f67891-34e5-4439-a8a4-2d9246775ff8   Facebook
# 3     537a727b-7525-44a3-99c8-8fdc488fbf02     Google
# 4     6a802b6c-4da8-4881-9ca6-4f69085c7c14    Twitter
# ...                                    ...        ...
# 2495  4f3de414-f0a7-4cf1-80b6-dad18f5cf1be  Affiliate
# 2496  b147382c-29d2-4801-a606-3d1d8f840082    Organic
# 2497  45afa7ae-0df9-42dc-ae22-6ea667085ef4  Affiliate
# 2498  0a25bd21-90ac-461d-903f-8ecf6dfc4af1    Twitter
# 2499  16abfe77-ec60-44cb-a749-3ea1e8845d06     Google
#
# [2500 rows x 13 columns]

# %%
#Dropping unneccasary columns
df_usersnew = df_users.drop(["password","address"],axis = 1)
df_usersnew.head()
# Out:
#    id                created_at                 name  \
# 0   1  2017-10-07T01:34:35.462Z         Hudson Borer
# 1   2  2018-04-09T12:10:05.167Z  Domenica Williamson
# 2   3  2017-06-27T06:06:20.625Z          Lina Heaney
# 3   4  2019-02-21T13:59:15.348Z         Arnold Adams
# 4   5  2017-09-05T03:36:44.811Z    Dominique Leffler
#
#                            email         city state    zip  birth_date  \
# 0         borer-hudson@yahoo.com   Wood River    NE  68883  1986-12-12
# 1  williamson-domenica@yahoo.com    Searsboro    IA  50242  1967-06-10
# 2          lina.heaney@yahoo.com    Sandstone    MN  55072  1961-12-18
# 3         adams.arnold@gmail.com          Rye    CO  81069  1992-08-12
# 4  leffler.dominique@hotmail.com  Beaver Dams    NY  14812  1974-04-20
#
#    latitude  longitude     source
# 0   40.7132   -98.5260    Twitter
# 1   41.5813   -92.6991  Affiliate
# 2   46.1197   -92.8416   Facebook
# 3   37.9203  -104.9730     Google
# 4   42.3490   -77.0567    Twitter

# %%
from datetime import datetime

def extract_date_and_duration(df, column_name="created_at"):
    """
    Extracts the date (first 10 characters) from a given datetime column 
    and calculates the duration (in days) from that date until today.

    Parameters:
    df (pd.DataFrame): The input DataFrame.
    column_name (str): The name of the column containing datetime strings.

    Returns:
    pd.DataFrame: The updated DataFrame with 'date_only' and 'days_since' columns.
    """
    df = df.copy()  # Avoid modifying the original DataFrame
    df["date_only"] = df[column_name].str[:10]  # Extract date part
    df["date_only"] = pd.to_datetime(df["date_only"])  # Convert to datetime format

    today = pd.to_datetime(datetime.today().date())  # Get today's date
    df["dayduration"] = (today - df["date_only"]).dt.days  # Calculate duration
    

    return df

# %%
dfuserstemp = extract_date_and_duration(df_usersnew)
df_usersclean = dfuserstemp.drop(["created_at","date_only"], axis= 1)
df_usersclean
# Out:
#         id                 name                          email         city  \
# 0        1         Hudson Borer         borer-hudson@yahoo.com   Wood River
# 1        2  Domenica Williamson  williamson-domenica@yahoo.com    Searsboro
# 2        3          Lina Heaney          lina.heaney@yahoo.com    Sandstone
# 3        4         Arnold Adams         adams.arnold@gmail.com          Rye
# 4        5    Dominique Leffler  leffler.dominique@hotmail.com  Beaver Dams
# ...    ...                  ...                            ...          ...
# 2495  2496          Jettie Yost          jettie-yost@gmail.com         Yuma
# 2496  2497         Sadye Gibson         sadye.gibson@gmail.com        Lewes
# 2497  2498        Verner Hamill        verner.hamill@gmail.com      Milford
# 2498  2499           Cloyd Beer           cloyd-beer@gmail.com      Spokane
# 2499  2500        Kenny Schmidt        kenny-schmidt@yahoo.com       Verona
#
#      state    zip  birth_date  latitude  longitude     source  dayduration
# 0       NE  68883  1986-12-12   40.7132   -98.5260    Twitter         2681
# 1       IA  50242  1967-06-10   41.5813   -92.6991  Affiliate         2497
# 2       MN  55072  1961-12-18   46.1197   -92.8416   Facebook         2783
# 3       CO  81069  1992-08-12   37.9203  -104.9730     Google         2179
# 4       NY  14812  1974-04-20   42.3490   -77.0567    Twitter         2713
# ...    ...    ...         ...       ...        ...        ...          ...
# 2495    CO  80759  1988-05-15   39.9009  -102.6890  Affiliate         2266
# 2496    DE  19958  1986-06-12   38.6579   -75.1427    Organic         2956
# 2497    UT  84751  1962-07-29   38.3279  -113.0120  Affiliate         3083
# 2498    WA  99217  1964-08-13   47.7267  -117.1940    Twitter         2878
# 2499    KY  41092  1962-02-23   38.8216   -84.6590     Google         2507
#
# [2500 rows x 11 columns]

# %% [markdown]
# # Initial Feature Engineering

# %% [markdown]
# ### Orders feature engineering

# %%
orderstemp = pd.merge(df_ordersnew, df_productsnew, how="inner", left_on="product_id", right_on="id")
orderstemp = orderstemp.drop(["id_y","rating","title", "vendor"], axis = 1)
orderstemp["total"] = orderstemp["price"] * orderstemp["quantity"]
orderstemp.rename(columns={"id_x": "id"})
orderstemp
# Out:
#         id_x                created_at  user_id  product_id  quantity  \
# 0          1  2019-02-11T21:40:27.892Z        1          14         2
# 1          2  2018-05-15T08:04:04.580Z        1         123         3
# 2          3  2019-12-06T22:22:48.544Z        1         105         2
# 3          4  2019-08-22T16:30:42.392Z        1          94         6
# 4          5  2018-10-10T03:34:47.309Z        1         132         5
# ...      ...                       ...      ...         ...       ...
# 18755  18756  2018-09-07T16:05:20.186Z     2499         165         4
# 18756  18757  2018-12-13T08:54:11.721Z     2499         131         2
# 18757  18758  2018-08-10T11:18:20.444Z     2499         127         7
# 18758  18759  2019-12-25T09:40:29.152Z     2500          45         2
# 18759  18760  2020-03-28T10:12:06.681Z     2500         138         1
#
#        date_only   category    price     total
# 0     2019-02-11     Widget  25.0988   50.1976
# 1     2018-05-15      Gizmo  73.9543  221.8629
# 2     2019-12-06     Gadget  35.1490   70.2980
# 3     2019-08-22     Widget  72.8124  436.8744
# 4     2018-10-10     Widget  85.2546  426.2730
# ...          ...        ...      ...       ...
# 18755 2018-09-07      Gizmo  25.5363  102.1452
# 18756 2018-12-13     Widget  75.4115  150.8230
# 18757 2018-08-10     Widget  89.6534  627.5738
# 18758 2019-12-25  Doohickey  78.6997  157.3994
# 18759 2020-03-28  Doohickey  75.9672   75.9672
#
# [18760 rows x 9 columns]

# %% [markdown]
# ### Reviews Feature Engineering

# %%
df_reviewsnew["review_length"] = df_reviewsnew["body"].str.len()
df_reviewsnew
# Out:
#         id          reviewer  product_id  rating  \
# 0        1            christ           1       5
# 1        2            xavier           1       4
# 2        3  cameron.nitzsche           1       5
# 3        4   barbara-shields           1       4
# 4        5           clement           1       5
# ...    ...               ...         ...     ...
# 1107  1108            dandre         200       4
# 1108  1109              will         200       3
# 1109  1110     cecilia.hyatt         200       4
# 1110  1111           delbert         200       5
# 1111  1112           terrell         200       4
#
#                                                    body  review_length
# 0     Ad perspiciatis quis et consectetur. Laboriosa...            171
# 1     Reprehenderit non error architecto consequatur...            237
# 2     In aut numquam labore fuga. Et tempora sit et ...            202
# 3     Est accusamus provident non animi labore minus...            158
# 4     Id sed sint corrupti molestias ad alias aut in...            138
# ...                                                 ...            ...
# 1107  Quia natus eaque odit aperiam quasi ea. Fugit ...            212
# 1108  Alias exercitationem quo aut rem accusamus quo...            172
# 1109  Et doloribus quo laudantium earum accusamus pa...            286
# 1110  Eligendi id adipisci quis quaerat est dolorem ...            235
# 1111  Eligendi cumque et quam qui. Quo facilis venia...            117
#
# [1112 rows x 6 columns]

# %% [markdown]
# ### Users Feature Engineering

# %%
df_usersclean["age"] = 2024 - df_usersclean["birth_date"].str[:4].astype(int)
df_usersclean.head()
# Out:
#    id                 name                          email         city state  \
# 0   1         Hudson Borer         borer-hudson@yahoo.com   Wood River    NE
# 1   2  Domenica Williamson  williamson-domenica@yahoo.com    Searsboro    IA
# 2   3          Lina Heaney          lina.heaney@yahoo.com    Sandstone    MN
# 3   4         Arnold Adams         adams.arnold@gmail.com          Rye    CO
# 4   5    Dominique Leffler  leffler.dominique@hotmail.com  Beaver Dams    NY
#
#      zip  birth_date  latitude  longitude     source  dayduration  age
# 0  68883  1986-12-12   40.7132   -98.5260    Twitter         2681   38
# 1  50242  1967-06-10   41.5813   -92.6991  Affiliate         2497   57
# 2  55072  1961-12-18   46.1197   -92.8416   Facebook         2783   63
# 3  81069  1992-08-12   37.9203  -104.9730     Google         2179   32
# 4  14812  1974-04-20   42.3490   -77.0567    Twitter         2713   50

# %% [markdown]
# ##

# %% [markdown]
# # Loading Data

# %%
orders_clean = orderstemp.copy()
products_clean = df_productsnew.copy()
reviews_clean = df_reviewsnew.copy()
users_clean = df_usersclean.copy()

# Save DataFrames to CSV files
orders_clean.to_csv("orders_clean.csv", index=False)
products_clean.to_csv("products_clean.csv", index=False)
reviews_clean.to_csv("reviews_clean.csv", index=False)
users_clean.to_csv("users_clean.csv", index=False)
